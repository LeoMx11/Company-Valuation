# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoMx11/Company-Valuation/blob/main/Company_Valuation_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello! This is sort of a part two to another project I am completing with my friend Eric where we predict the change in...

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://stockanalysis.com/list/biggest-companies/", "html")

soup = BeautifulSoup(page.text, 'html.parser')

text = str(soup)

# %%
def getHtml(url):

  page = requests.get(url, "html")

  soup = BeautifulSoup(page.text, 'html.parser')

  text = str(soup)

  return text

# %%
check = 0

text1 = text

TickerList = []

while check == 0:

  text1 = text1[text1.find('<a href="/stocks/') + 1:]
  text1 = text1[text1.find('>')+1:]

  TickerList.append(text1[:text1.find('<')])

  if text1.find('<a href="/stocks/') == -1:
    check = 1
# Out:
# 500

# %%
import yfinance as yf
import pandas as pd

# %%
def mostRecentQtrDate(ticker):

  return str(yf.Ticker(ticker).get_financials(freq="quarterly").keys()[0])[:10]

# %%
bigDf = pd.DataFrame()

for stock in TickerList:

  concatThis = pd.DataFrame()

  try: concatThis[stock] = yf.Ticker(stock).get_financials(freq = "quarterly")[mostRecentQtrDate(stock)]
  except: pass

  try: bigDf = pd.concat([bigDf, concatThis], axis = 1)
  except: pass

bigDf.head()
# Out:
#                                                              AAPL  \
# TaxEffectOfUnusualItems                                       0.0
# TaxRateForCalcs                                              0.21
# NormalizedEBITDA                                    45912000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  36330000000.0
# ReconciledDepreciation                               3080000000.0
# ...                                                           ...
# PolicyholderBenefitsGross                                     NaN
# DepletionIncomeStatement                                      NaN
# NetIncomeFromTaxLossCarryforward                              NaN
# PolicyholderBenefitsCeded                                     NaN
# SecuritiesAmortization                                        NaN
#
#                                                              MSFT  \
# TaxEffectOfUnusualItems                              -203220000.0
# TaxRateForCalcs                                              0.18
# NormalizedEBITDA                                    37915000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  24108000000.0
# ReconciledDepreciation                               6827000000.0
# ...                                                           ...
# PolicyholderBenefitsGross                                     NaN
# DepletionIncomeStatement                                      NaN
# NetIncomeFromTaxLossCarryforward                              NaN
# PolicyholderBenefitsCeded                                     NaN
# SecuritiesAmortization                                        NaN
#
#                                                              NVDA  \
# TaxEffectOfUnusualItems                                       0.0
# TaxRateForCalcs                                             0.135
# NormalizedEBITDA                                    22855000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  19309000000.0
# ReconciledDepreciation                                478000000.0
# ...                                                           ...
# PolicyholderBenefitsGross                                     NaN
# DepletionIncomeStatement                                      NaN
# NetIncomeFromTaxLossCarryforward                              NaN
# PolicyholderBenefitsCeded                                     NaN
# SecuritiesAmortization                                        NaN
#
#                                                               AMZN  \
# TaxEffectOfUnusualItems                            -2700449.076897
# TaxRateForCalcs                                           0.150025
# NormalizedEBITDA                                     32100000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   15328000000.0
# ReconciledDepreciation                               13442000000.0
# ...                                                            ...
# PolicyholderBenefitsGross                                      NaN
# DepletionIncomeStatement                                       NaN
# NetIncomeFromTaxLossCarryforward                               NaN
# PolicyholderBenefitsCeded                                      NaN
# SecuritiesAmortization                                         NaN
#
#                                                             GOOGL  \
# TaxEffectOfUnusualItems                               340680000.0
# TaxRateForCalcs                                              0.17
# NormalizedEBITDA                                    33741000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  26301000000.0
# ReconciledDepreciation                               3985000000.0
# ...                                                           ...
# PolicyholderBenefitsGross                                     NaN
# DepletionIncomeStatement                                      NaN
# NetIncomeFromTaxLossCarryforward                              NaN
# PolicyholderBenefitsCeded                                     NaN
# SecuritiesAmortization                                        NaN
#
#                                                              META  \
# TaxEffectOfUnusualItems                             -44365234.375
# TaxRateForCalcs                                          0.115234
# NormalizedEBITDA                                    28648000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  20838000000.0
# ReconciledDepreciation                               4460000000.0
# ...                                                           ...
# PolicyholderBenefitsGross                                     NaN
# DepletionIncomeStatement                                      NaN
# NetIncomeFromTaxLossCarryforward                              NaN
# PolicyholderBenefitsCeded                                     NaN
# SecuritiesAmortization                                        NaN
#
#                                                               TSLA  \
# TaxEffectOfUnusualItems                            -1098336.948662
# TaxRateForCalcs                                           0.156905
# NormalizedEBITDA                                      4365000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...    2356000000.0
# ReconciledDepreciation                                1496000000.0
# ...                                                            ...
# PolicyholderBenefitsGross                                      NaN
# DepletionIncomeStatement                                       NaN
# NetIncomeFromTaxLossCarryforward                               NaN
# PolicyholderBenefitsCeded                                      NaN
# SecuritiesAmortization                                         NaN
#
#                                                             AVGO  \
# TaxEffectOfUnusualItems                              -69300000.0
# TaxRateForCalcs                                             0.21
# NormalizedEBITDA                                    7620000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  4205000000.0
# ReconciledDepreciation                              2611000000.0
# ...                                                          ...
# PolicyholderBenefitsGross                                    NaN
# DepletionIncomeStatement                                     NaN
# NetIncomeFromTaxLossCarryforward                             NaN
# PolicyholderBenefitsCeded                                    NaN
# SecuritiesAmortization                                       NaN
#
#                                                                TSM  \
# TaxEffectOfUnusualItems                                        0.0
# TaxRateForCalcs                                           0.165618
# NormalizedEBITDA                                    596091000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  374680000000.0
# ReconciledDepreciation                              170378000000.0
# ...                                                            ...
# PolicyholderBenefitsGross                                      NaN
# DepletionIncomeStatement                                       NaN
# NetIncomeFromTaxLossCarryforward                               NaN
# PolicyholderBenefitsCeded                                      NaN
# SecuritiesAmortization                                         NaN
#
#                                                              WMT  ...  \
# TaxEffectOfUnusualItems                                      0.0  ...
# TaxRateForCalcs                                            0.227  ...
# NormalizedEBITDA                                    9976000000.0  ...
# NetIncomeFromContinuingOperationNetMinorityInte...  4577000000.0  ...
# ReconciledDepreciation                              3260000000.0  ...
# ...                                                          ...  ...
# PolicyholderBenefitsGross                                    NaN  ...
# DepletionIncomeStatement                                     NaN  ...
# NetIncomeFromTaxLossCarryforward                             NaN  ...
# PolicyholderBenefitsCeded                                    NaN  ...
# SecuritiesAmortization                                       NaN  ...
#
#                                                           FWONA          MKL  \
# TaxEffectOfUnusualItems                               7560000.0          0.0
# TaxRateForCalcs                                            0.21     0.215037
# NormalizedEBITDA                                    221000000.0          NaN
# NetIncomeFromContinuingOperationNetMinorityInte...  117000000.0  904959000.0
# ReconciledDepreciation                               88000000.0   46459000.0
# ...                                                         ...          ...
# PolicyholderBenefitsGross                                   NaN          NaN
# DepletionIncomeStatement                                    NaN          NaN
# NetIncomeFromTaxLossCarryforward                            NaN          NaN
# PolicyholderBenefitsCeded                                   NaN          NaN
# SecuritiesAmortization                                      NaN          NaN
#
#                                                                EXE  \
# TaxEffectOfUnusualItems                            -2506329.113924
# TaxRateForCalcs                                           0.278481
# NormalizedEBITDA                                       209000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...    -114000000.0
# ReconciledDepreciation                                 335000000.0
# ...                                                            ...
# PolicyholderBenefitsGross                                      NaN
# DepletionIncomeStatement                                       NaN
# NetIncomeFromTaxLossCarryforward                               NaN
# PolicyholderBenefitsCeded                                      NaN
# SecuritiesAmortization                                         NaN
#
#                                                                  ASX  \
# TaxEffectOfUnusualItems                             158657259.380098
# TaxRateForCalcs                                             0.167537
# NormalizedEBITDA                                       27641000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...      9666000000.0
# ReconciledDepreciation                                 15037000000.0
# ...                                                              ...
# PolicyholderBenefitsGross                                        NaN
# DepletionIncomeStatement                                         NaN
# NetIncomeFromTaxLossCarryforward                                 NaN
# PolicyholderBenefitsCeded                                        NaN
# SecuritiesAmortization                                           NaN
#
#                                                             FOXA  \
# TaxEffectOfUnusualItems                               52500000.0
# TaxRateForCalcs                                             0.25
# NormalizedEBITDA                                    1096000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   827000000.0
# ReconciledDepreciation                                91000000.0
# ...                                                          ...
# PolicyholderBenefitsGross                                    NaN
# DepletionIncomeStatement                                     NaN
# NetIncomeFromTaxLossCarryforward                             NaN
# PolicyholderBenefitsCeded                                    NaN
# SecuritiesAmortization                                       NaN
#
#                                                               LI        NTRA  \
# TaxEffectOfUnusualItems                                      0.0         0.0
# TaxRateForCalcs                                         0.170512        0.21
# NormalizedEBITDA                                    3476425000.0 -19520000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  2814262000.0 -31592000.0
# ReconciledDepreciation                                       NaN   8200000.0
# ...                                                          ...         ...
# PolicyholderBenefitsGross                                    NaN         NaN
# DepletionIncomeStatement                                     NaN         NaN
# NetIncomeFromTaxLossCarryforward                             NaN         NaN
# PolicyholderBenefitsCeded                                    NaN         NaN
# SecuritiesAmortization                                       NaN         NaN
#
#                                                             PHM          PTC  \
# TaxEffectOfUnusualItems                              -1088360.0          0.0
# TaxRateForCalcs                                            0.23     0.256818
# NormalizedEBITDA                                    933132000.0  232185000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  697914000.0  126523000.0
# ReconciledDepreciation                               22084000.0   36992000.0
# ...                                                         ...          ...
# PolicyholderBenefitsGross                                   NaN          NaN
# DepletionIncomeStatement                                    NaN          NaN
# NetIncomeFromTaxLossCarryforward                            NaN          NaN
# PolicyholderBenefitsCeded                                   NaN          NaN
# SecuritiesAmortization                                      NaN          NaN
#
#                                                           TOST
# TaxEffectOfUnusualItems                               -16000.0
# TaxRateForCalcs                                          0.016
# NormalizedEBITDA                                    47000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  56000000.0
# ReconciledDepreciation                              12000000.0
# ...                                                        ...
# PolicyholderBenefitsGross                                  NaN
# DepletionIncomeStatement                                   NaN
# NetIncomeFromTaxLossCarryforward                           NaN
# PolicyholderBenefitsCeded                                  NaN
# SecuritiesAmortization                                     NaN
#
# [84 rows x 486 columns]

# %%
bigDf = bigDf.fillna(0)

columnList = bigDf.columns

rowMeans = bigDf.mean(axis=1)

rowMeans
# Out:
# <ipython-input-9-19e2ad0c303c>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bigDf = bigDf.fillna(0)
# TaxEffectOfUnusualItems                               -2.034045e+08
# TaxRateForCalcs                                        1.962338e-01
# NormalizedEBITDA                                       1.069576e+10
# NetIncomeFromContinuingOperationNetMinorityInterest    1.150527e+10
# ReconciledDepreciation                                 4.339297e+09
#                                                            ...
# PolicyholderBenefitsGross                              1.241481e+08
# DepletionIncomeStatement                               6.802469e+05
# NetIncomeFromTaxLossCarryforward                      -7.613169e+04
# PolicyholderBenefitsCeded                              1.378601e+05
# SecuritiesAmortization                                -1.367078e+04
# Length: 84, dtype: float64

# %%
len(columnList)

bigDf = bigDf.div(rowMeans, axis=0)

# %%
import torch

# %%
bigTensor = torch.from_numpy(bigDf.to_numpy().transpose()).type(torch.float)

# %%
bigTensor
# Out:
# tensor([[-0.0000e+00, 1.0702e+00, 4.2925e+00,  ..., -0.0000e+00, 0.0000e+00,
#          -0.0000e+00],
#         [9.9909e-01, 9.1727e-01, 3.5449e+00,  ..., -0.0000e+00, 0.0000e+00,
#          -0.0000e+00],
#         [-0.0000e+00, 6.8795e-01, 2.1368e+00,  ..., -0.0000e+00, 0.0000e+00,
#          -0.0000e+00],
#         ...,
#         [5.3507e-03, 1.1721e+00, 8.7243e-02,  ..., -0.0000e+00, 0.0000e+00,
#          -0.0000e+00],
#         [-0.0000e+00, 1.3087e+00, 2.1708e-02,  ..., -0.0000e+00, 0.0000e+00,
#          -0.0000e+00],
#         [7.8661e-05, 8.1535e-02, 4.3943e-03,  ..., -0.0000e+00, 0.0000e+00,
#          -0.0000e+00]])

# %%
PriceList = []

i=0

for ticker in list(columnList):

  try: PriceList.append((yf.Ticker(ticker).history(period="80d")["Open"].iloc[1]))
  except:
    print(ticker + " failed")
    bigTensor = torch.cat((bigTensor[:i], bigTensor[i+1:]))
    columnList = columnList.drop(ticker)

  i+=1

print(len(PriceList))
print(len(columnList))
# Out:
# 486
# 486

# %%
from sklearn.model_selection import train_test_split

# %%
dataTrain, dataTest, priceTrain, priceTest = train_test_split(bigTensor, torch.tensor(PriceList), test_size=0.2, random_state=42)

# %%
dataTrain = torch.nan_to_num(dataTrain, nan=0.0)
dataTest = torch.nan_to_num(dataTest, nan=0.0)

# %%
priceTrain = priceTrain.type(torch.float)
priceTest = priceTest.type(torch.float)

# %%
# import necessary stuff
import torch
from torch import nn

# make device agnostic code
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
# construct model
class StockPriceModel1(nn.Module):
  def __init__(self):
    super().__init__()

    self.layer1 = nn.Linear(in_features=84,
                            out_features=20)

    self.layer2 = nn.Linear(in_features=20,
                            out_features=5)

    self.layer3 = nn.Linear(in_features=5,
                            out_features=1)

    self.relu = nn.ReLU()

  def forward(self, x):
    return self.layer3(self.layer2(self.relu(self.layer1(x))))

# %%
model_0 = StockPriceModel1().to(device)
model_0.state_dict()
# Out:
# OrderedDict([('layer1.weight',
#               tensor([[ 0.0190, -0.0284,  0.0520,  ..., -0.0084,  0.1015,  0.0285],
#                       [-0.0290, -0.0660, -0.0381,  ..., -0.0758, -0.0611,  0.0598],
#                       [ 0.0857, -0.0826,  0.0428,  ...,  0.0172,  0.0014,  0.0215],
#                       ...,
#                       [-0.0127, -0.0937, -0.0882,  ..., -0.0570,  0.0285,  0.0998],
#                       [ 0.0083,  0.0988, -0.1028,  ...,  0.0547, -0.0012,  0.0275],
#                       [-0.0056,  0.0977,  0.0965,  ..., -0.0370,  0.0106, -0.0648]])),
#              ('layer1.bias',
#               tensor([ 0.0295, -0.0051,  0.0871,  0.0683,  0.0353,  0.0913,  0.0702, -0.0770,
#                        0.0012,  0.0646,  0.0497,  0.0204,  0.0833,  0.0225,  0.0330,  0.0071,
#                        0.0236,  0.0080, -0.0794,  0.0489])),
#              ('layer2.weight',
#               tensor([[-0.0719, -0.1768,  0.1488,  0.0538,  0.1951, -0.1765,  0.2199,  0.0524,
#                        -0.1141, -0.2054, -0.1208, -0.0811,  0.1117, -0.0388,  0.1563,  0.1374,
#                        -0.0123, -0.0836,  0.2189, -0.0059],
#                       [ 0.1769,  0.1687,  0.2123, -0.1944, -0.1012,  0.0043, -0.0557, -0.0711,
#                        -0.1065,  0.1096,  0.1421,  0.1660,  0.0582,  0.1501,  0.0887, -0.2007,
#                         0.1598, -0.1528,  0.2062, -0.1800],
#                       [-0.0876, -0.1570,  0.0824,  0.2070, -0.1546,  0.1899,  0.1583, -0.1588,
#                         0.0475,  0.0825,  0.0611,  0.1162, -0.1708,  0.2193,  0.1695,  0.1002,
#                         0.2209, -0.0762,  0.0879, -0.1398],
#                       [-0.0765, -0.0137, -0.0179,  0.0398, -0.1165, -0.0788, -0.1431,  0.1316,
#                        -0.1510, -0.0742,  0.1832, -0.0073,  0.0213, -0.0600,  0.0190,  0.0289,
#                         0.0701,  0.0277,  0.1881,  0.0345],
#                       [ 0.0195,  0.1601, -0.0935,  0.1021,  0.1757,  0.0161, -0.1110, -0.2071,
#                        -0.2097,  0.0945, -0.2214, -0.1411,  0.0469,  0.0583,  0.0910, -0.1250,
#                         0.1968,  0.2176, -0.1588, -0.1279]])),
#              ('layer2.bias',
#               tensor([-0.0702,  0.1373, -0.1091, -0.0539,  0.0708])),
#              ('layer3.weight',
#               tensor([[ 0.3091, -0.2179, -0.3181,  0.1439,  0.1258]])),
#              ('layer3.bias', tensor([-0.4415]))])

# %%
optimizer = torch.optim.SGD(params = model_0.parameters(),
                            lr=0.001)
loss_fn = torch.nn.functional.l1_loss

# %%
def accuracy_fn(priceTrue, pricePred):

  total = 0

  for i in range(len(pricePred)):
    error = torch.abs(pricePred[i]-priceTrue[i]) / priceTrue[i]
    if error < 0.4:
      total += 1

  return total / len(pricePred)

# %%
nn.functional.l1_loss(torch.tensor([3.0]), torch.tensor([5.0]))
# Out:
# tensor(2.)

# %%
epochs = 1000

for epoch in range(epochs):

  model_0.train()

  #forward pass
  price_preds = model_0(dataTrain).squeeze()

  #calculate loss
  loss = loss_fn(price_preds, priceTrain)

  acc = accuracy_fn(priceTrue=priceTrain,
                   pricePred=price_preds)

  # optimizer zero grad
  optimizer.zero_grad()

  # perform backpropagation
  loss.backward()

  # optimizer step
  optimizer.step()

  # TESTING
  model_0.eval()
  with torch.inference_mode():

    price_test_preds = model_0(dataTest).squeeze()

    test_loss = loss_fn(price_test_preds,priceTest)
    test_acc = accuracy_fn(priceTest, price_test_preds)

  if epoch % 100 == 0:
    print(f"Epoch: {epoch} | Loss: {loss} | Acc: {acc}")
    print(f"Test Loss: {test_loss} | Test acc: {test_acc}")
# Out:
# Epoch: 0 | Loss: 119.40908813476562 | Acc: 0.5463917525773195
# Test Loss: 143.87086486816406 | Test acc: 0.40816326530612246
# Epoch: 100 | Loss: 121.79678344726562 | Acc: 0.5489690721649485
# Test Loss: 149.29063415527344 | Test acc: 0.3877551020408163
# Epoch: 200 | Loss: 120.52303314208984 | Acc: 0.5360824742268041
# Test Loss: 154.8955078125 | Test acc: 0.40816326530612246
# Epoch: 300 | Loss: 121.7148666381836 | Acc: 0.5438144329896907
# Test Loss: 146.0621795654297 | Test acc: 0.3979591836734694
# Epoch: 400 | Loss: 117.8634033203125 | Acc: 0.5438144329896907
# Test Loss: 169.03114318847656 | Test acc: 0.3673469387755102
# Epoch: 500 | Loss: 127.0459213256836 | Acc: 0.5438144329896907
# Test Loss: 142.14878845214844 | Test acc: 0.41836734693877553
# Epoch: 600 | Loss: 126.38417053222656 | Acc: 0.5463917525773195
# Test Loss: 154.7152099609375 | Test acc: 0.40816326530612246
# Epoch: 700 | Loss: 127.1956787109375 | Acc: 0.5618556701030928
# Test Loss: 162.23765563964844 | Test acc: 0.3979591836734694
# Epoch: 800 | Loss: 131.06590270996094 | Acc: 0.5541237113402062
# Test Loss: 156.09677124023438 | Test acc: 0.3673469387755102
# Epoch: 900 | Loss: 114.60617065429688 | Acc: 0.5618556701030928
# Test Loss: 168.3233642578125 | Test acc: 0.3673469387755102

# %% [markdown]
# These models only ever seem to have about as much accuracy as the error that I allow (i.e. if I say it has to be below 50% error, about 50% of the predictions will be within the range). To call this insignificant would be an understatement. Next, instead of just letting every single parameter have a say in the valuation, I will do some actual research into some valuation metrics and test which ones are the most accurate.
